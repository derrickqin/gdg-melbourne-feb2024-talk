# %% [markdown]
# # Retrieval Augmented Generation with Google Gemini and BigQuery

# %% [markdown]
# ## Install libraries

# %%
# %pip install --upgrade --quiet  langchain langchain-google-vertexai google-cloud-bigquery unstructured beautifulsoup4

# %% [markdown]
# ## Set up

# %%
# !gcloud config set project derrick-doit-sandbox --quiet
# Out:
# Updated property [core/project].

# %% [markdown]
# ### Create BigQuery Dataset

# %%
PROJECT_ID = "derrick-doit-sandbox"
REGION = "US"
DATASET = "vector_search"
TABLE = "doc_and_vectors"
SITEMAP='https://docs.flutter.dev/sitemap.xml'

# %%
from google.cloud import bigquery

client = bigquery.Client(project=PROJECT_ID, location=REGION)
client.create_dataset(dataset=DATASET, exists_ok=True)
# Out:
# Dataset(DatasetReference('derrick-doit-sandbox', 'vector_search'))

# %% [markdown]
# ### Embeddings
#
# Embeddings are a way to store data of all types (including images, audio files, text, documents, etc.) in number arrays called vectors.
#
# Vertex AI Embeddings for Text has an embedding space with 768 dimensions.
#
# Let's visualize the embedding space of the 8 million Stack Overflow questions!

# %% [markdown]
# ![link text](https://storage.googleapis.com/gweb-cloudblog-publish/images/4._Nomic_AI_Atlas.max-2200x2200.png)
# Credit to:
# - https://atlas.nomic.ai/
# - https://cloud.google.com/blog/products/ai-machine-learning/how-to-use-grounding-for-your-llms-with-text-embeddings

# %% [markdown]
# ### Use Vertex AI Embeddings model

# %%
from langchain_google_vertexai import VertexAIEmbeddings

embedding = VertexAIEmbeddings(
    model_name="textembedding-gecko@001", project=PROJECT_ID
)

# %% [markdown]
# ### Use BigQuery as Vector Store

# %%
from langchain.vectorstores.utils import DistanceStrategy
from langchain_community.vectorstores import BigQueryVectorSearch

# %%
### Patch BigQueryVectorSearch
from typing import Any, Dict, List, Optional, Tuple
from langchain_core.documents import Document
import json

DEFAULT_TOP_K = 4  # default number of documents returned from similarity search

class PatchedBigQueryVectorSearch(BigQueryVectorSearch):
    def _search_with_score_and_embeddings_by_vector(
        self,
        embedding: List[float],
        k: int = DEFAULT_TOP_K,
        filter: Optional[Dict[str, Any]] = None,
        brute_force: bool = False,
        fraction_lists_to_search: Optional[float] = None,
    ) -> List[Tuple[Document, List[float], float]]:
        from google.cloud import bigquery

        # Create an index if no index exists.
        if not self._have_index and not self._creating_index:
            self._initialize_vector_index()
        # Prepare filter
        filter_expr = "TRUE"
        if filter:
            filter_expressions = []
            for i in filter.items():
                if isinstance(i[1], float):
                    expr = (
                        "ABS(CAST(JSON_VALUE("
                        f"base.`{self.metadata_field}`,'$.{i[0]}') "
                        f"AS FLOAT64) - {i[1]}) "
                        f"<= {sys.float_info.epsilon}"
                    )
                else:
                    val = str(i[1]).replace('"', '\\"')
                    expr = (
                        f"JSON_VALUE(base.`{self.metadata_field}`,'$.{i[0]}')"
                        f' = "{val}"'
                    )
                filter_expressions.append(expr)
            filter_expression_str = " AND ".join(filter_expressions)
            filter_expr += f" AND ({filter_expression_str})"
        # Configure and run a query job.
        job_config = bigquery.QueryJobConfig(
            query_parameters=[
                bigquery.ArrayQueryParameter("v", "FLOAT64", embedding),
            ],
            use_query_cache=False,
            priority=bigquery.QueryPriority.BATCH,
        )
        if self.distance_strategy == DistanceStrategy.EUCLIDEAN_DISTANCE:
            distance_type = "EUCLIDEAN"
        elif self.distance_strategy == DistanceStrategy.COSINE:
            distance_type = "COSINE"
        # Default to EUCLIDEAN_DISTANCE
        else:
            distance_type = "EUCLIDEAN"
        if brute_force:
            options_string = ",options => '{\"use_brute_force\":true}'"
        elif fraction_lists_to_search:
            if fraction_lists_to_search == 0 or fraction_lists_to_search >= 1.0:
                raise ValueError(
                    "`fraction_lists_to_search` must be between " "0.0 and 1.0"
                )
            options_string = (
                ',options => \'{"fraction_lists_to_search":'
                f"{fraction_lists_to_search}}}'"
            )
        else:
            options_string = ""
        query = f"""
            SELECT
                base.*,
                distance AS _vector_search_distance
            FROM VECTOR_SEARCH(
                TABLE `{self.full_table_id}`,
                "{self.text_embedding_field}",
                (SELECT @v AS {self.text_embedding_field}),
                distance_type => "{distance_type}",
                top_k => {k}
                {options_string}
            )
            WHERE {filter_expr}
            LIMIT {k}
        """
        document_tuples: List[Tuple[Document, List[float], float]] = []
        # TODO(vladkol): Use jobCreationMode=JOB_CREATION_OPTIONAL when available.
        job = self.bq_client.query(
            query, job_config=job_config, api_method=bigquery.enums.QueryApiMethod.QUERY
        )
        # Process job results.
        for row in job:
            metadata = row[self.metadata_field]
            if metadata:
                metadata = json.loads(json.dumps(metadata))
            else:
                metadata = {}
            metadata["__id"] = row[self.doc_id_field]
            metadata["__job_id"] = job.job_id
            doc = Document(page_content=row[self.content_field], metadata=metadata)
            document_tuples.append(
                (doc, row[self.text_embedding_field], row["_vector_search_distance"])
            )
        return document_tuples

# %%
store = PatchedBigQueryVectorSearch(
    project_id=PROJECT_ID,
    dataset_name=DATASET,
    table_name=TABLE,
    location=REGION,
    embedding=embedding,
    distance_strategy=DistanceStrategy.EUCLIDEAN_DISTANCE,
)

# %% [markdown]
# # Document processing

# %% [markdown]
# ## Parse the sitemap

# %%
import requests
from bs4 import BeautifulSoup

def parse_sitemap(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "xml")
    urls = [element.text for element in soup.find_all("loc")]
    return urls

sites = parse_sitemap(SITEMAP)

# %%
sites_filtered = [url for url in sites if '.css' not in url and '.json' not in url]
sites_filtered
# Out:
# ['https://docs.flutter.dev',
#  'https://docs.flutter.dev/404',
#  'https://docs.flutter.dev/add-to-app',
#  'https://docs.flutter.dev/add-to-app/android',
#  'https://docs.flutter.dev/add-to-app/android/add-flutter-fragment',
#  'https://docs.flutter.dev/add-to-app/android/add-flutter-screen',
#  'https://docs.flutter.dev/add-to-app/android/add-flutter-view',
#  'https://docs.flutter.dev/add-to-app/android/plugin-setup',
#  'https://docs.flutter.dev/add-to-app/android/project-setup',
#  'https://docs.flutter.dev/add-to-app/debugging',
#  'https://docs.flutter.dev/add-to-app/ios',
#  'https://docs.flutter.dev/add-to-app/ios/add-flutter-screen',
#  'https://docs.flutter.dev/add-to-app/ios/project-setup',
#  'https://docs.flutter.dev/add-to-app/multiple-flutters',
#  'https://docs.flutter.dev/add-to-app/performance',
#  'https://docs.flutter.dev/brand',
#  'https://docs.flutter.dev/codelabs',
#  'https://docs.flutter.dev/codelabs/implicit-animations',
#  'https://docs.flutter.dev/community/china',
#  'https://docs.flutter.dev/cookbook',
#  'https://docs.flutter.dev/cookbook/animation',
#  'https://docs.flutter.dev/cookbook/animation/animated-container',
#  'https://docs.flutter.dev/cookbook/animation/opacity-animation',
#  'https://docs.flutter.dev/cookbook/animation/page-route-animation',
#  'https://docs.flutter.dev/cookbook/animation/physics-simulation',
#  'https://docs.flutter.dev/cookbook/design',
#  'https://docs.flutter.dev/cookbook/design/drawer',
#  'https://docs.flutter.dev/cookbook/design/fonts',
#  'https://docs.flutter.dev/cookbook/design/orientation',
#  'https://docs.flutter.dev/cookbook/design/package-fonts',
#  'https://docs.flutter.dev/cookbook/design/snackbars',
#  'https://docs.flutter.dev/cookbook/design/tabs',
#  'https://docs.flutter.dev/cookbook/design/themes',
#  'https://docs.flutter.dev/cookbook/effects',
#  'https://docs.flutter.dev/cookbook/effects/download-button',
#  'https://docs.flutter.dev/cookbook/effects/drag-a-widget',
#  'https://docs.flutter.dev/cookbook/effects/expandable-fab',
#  'https://docs.flutter.dev/cookbook/effects/gradient-bubbles',
#  'https://docs.flutter.dev/cookbook/effects/nested-nav',
#  'https://docs.flutter.dev/cookbook/effects/parallax-scrolling',
#  'https://docs.flutter.dev/cookbook/effects/photo-filter-carousel',
#  'https://docs.flutter.dev/cookbook/effects/shimmer-loading',
#  'https://docs.flutter.dev/cookbook/effects/staggered-menu-animation',
#  'https://docs.flutter.dev/cookbook/effects/typing-indicator',
#  'https://docs.flutter.dev/cookbook/forms',
#  'https://docs.flutter.dev/cookbook/forms/focus',
#  'https://docs.flutter.dev/cookbook/forms/retrieve-input',
#  'https://docs.flutter.dev/cookbook/forms/text-field-changes',
#  'https://docs.flutter.dev/cookbook/forms/text-input',
#  'https://docs.flutter.dev/cookbook/forms/validation',
#  'https://docs.flutter.dev/cookbook/games',
#  'https://docs.flutter.dev/cookbook/games/achievements-leaderboard',
#  'https://docs.flutter.dev/cookbook/games/firestore-multiplayer',
#  'https://docs.flutter.dev/cookbook/gestures',
#  'https://docs.flutter.dev/cookbook/gestures/dismissible',
#  'https://docs.flutter.dev/cookbook/gestures/handling-taps',
#  'https://docs.flutter.dev/cookbook/gestures/ripples',
#  'https://docs.flutter.dev/cookbook/images',
#  'https://docs.flutter.dev/cookbook/images/fading-in-images',
#  'https://docs.flutter.dev/cookbook/images/network-image',
#  'https://docs.flutter.dev/cookbook/lists',
#  'https://docs.flutter.dev/cookbook/lists/basic-list',
#  'https://docs.flutter.dev/cookbook/lists/floating-app-bar',
#  'https://docs.flutter.dev/cookbook/lists/grid-lists',
#  'https://docs.flutter.dev/cookbook/lists/horizontal-list',
#  'https://docs.flutter.dev/cookbook/lists/long-lists',
#  'https://docs.flutter.dev/cookbook/lists/mixed-list',
#  'https://docs.flutter.dev/cookbook/lists/spaced-items',
#  'https://docs.flutter.dev/cookbook/maintenance',
#  'https://docs.flutter.dev/cookbook/maintenance/error-reporting',
#  'https://docs.flutter.dev/cookbook/navigation',
#  'https://docs.flutter.dev/cookbook/navigation/hero-animations',
#  'https://docs.flutter.dev/cookbook/navigation/named-routes',
#  'https://docs.flutter.dev/cookbook/navigation/navigate-with-arguments',
#  'https://docs.flutter.dev/cookbook/navigation/navigation-basics',
#  'https://docs.flutter.dev/cookbook/navigation/passing-data',
#  'https://docs.flutter.dev/cookbook/navigation/returning-data',
#  'https://docs.flutter.dev/cookbook/navigation/set-up-app-links',
#  'https://docs.flutter.dev/cookbook/navigation/set-up-universal-links',
#  'https://docs.flutter.dev/cookbook/networking',
#  'https://docs.flutter.dev/cookbook/networking/authenticated-requests',
#  'https://docs.flutter.dev/cookbook/networking/background-parsing',
#  'https://docs.flutter.dev/cookbook/networking/delete-data',
#  'https://docs.flutter.dev/cookbook/networking/fetch-data',
#  'https://docs.flutter.dev/cookbook/networking/send-data',
#  'https://docs.flutter.dev/cookbook/networking/update-data',
#  'https://docs.flutter.dev/cookbook/networking/web-sockets',
#  'https://docs.flutter.dev/cookbook/persistence',
#  'https://docs.flutter.dev/cookbook/persistence/key-value',
#  'https://docs.flutter.dev/cookbook/persistence/reading-writing-files',
#  'https://docs.flutter.dev/cookbook/persistence/sqlite',
#  'https://docs.flutter.dev/cookbook/plugins',
#  'https://docs.flutter.dev/cookbook/plugins/google-mobile-ads',
#  'https://docs.flutter.dev/cookbook/plugins/picture-using-camera',
#  'https://docs.flutter.dev/cookbook/plugins/play-video',
#  'https://docs.flutter.dev/cookbook/testing',
#  'https://docs.flutter.dev/cookbook/testing/integration',
#  'https://docs.flutter.dev/cookbook/testing/integration/introduction',
#  'https://docs.flutter.dev/cookbook/testing/integration/profiling',
#  'https://docs.flutter.dev/cookbook/testing/unit',
#  'https://docs.flutter.dev/cookbook/testing/unit/introduction',
#  'https://docs.flutter.dev/cookbook/testing/unit/mocking',
#  'https://docs.flutter.dev/cookbook/testing/widget',
#  'https://docs.flutter.dev/cookbook/testing/widget/finders',
#  'https://docs.flutter.dev/cookbook/testing/widget/introduction',
#  'https://docs.flutter.dev/cookbook/testing/widget/scrolling',
#  'https://docs.flutter.dev/cookbook/testing/widget/tap-drag',
#  'https://docs.flutter.dev/dash',
#  'https://docs.flutter.dev/data-and-backend',
#  'https://docs.flutter.dev/data-and-backend/firebase',
#  'https://docs.flutter.dev/data-and-backend/google-apis',
#  'https://docs.flutter.dev/data-and-backend/networking',
#  'https://docs.flutter.dev/data-and-backend/persistence',
#  'https://docs.flutter.dev/data-and-backend/serialization',
#  'https://docs.flutter.dev/data-and-backend/serialization/json',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt/declarative',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt/ephemeral-vs-app',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt/intro',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt/options',
#  'https://docs.flutter.dev/data-and-backend/state-mgmt/simple',
#  'https://docs.flutter.dev/deployment',
#  'https://docs.flutter.dev/deployment/android',
#  'https://docs.flutter.dev/deployment/cd',
#  'https://docs.flutter.dev/deployment/flavors',
#  'https://docs.flutter.dev/deployment/ios',
#  'https://docs.flutter.dev/deployment/linux',
#  'https://docs.flutter.dev/deployment/macos',
#  'https://docs.flutter.dev/deployment/obfuscate',
#  'https://docs.flutter.dev/deployment/web',
#  'https://docs.flutter.dev/deployment/windows',
#  'https://docs.flutter.dev/embedded',
#  'https://docs.flutter.dev/get-started',
#  'https://docs.flutter.dev/get-started/codelab-web',
#  'https://docs.flutter.dev/get-started/codelab',
#  'https://docs.flutter.dev/get-started/editor',
#  'https://docs.flutter.dev/get-started/flutter-for/android-devs',
#  'https://docs.flutter.dev/get-started/flutter-for/dart-swift-concurrency',
#  'https://docs.flutter.dev/get-started/flutter-for/declarative',
#  'https://docs.flutter.dev/get-started/flutter-for/react-native-devs',
#  'https://docs.flutter.dev/get-started/flutter-for/swiftui-devs',
#  'https://docs.flutter.dev/get-started/flutter-for/uikit-devs',
#  'https://docs.flutter.dev/get-started/flutter-for/web-devs',
#  'https://docs.flutter.dev/get-started/flutter-for/xamarin-forms-devs',
#  'https://docs.flutter.dev/get-started/fwe/layout',
#  'https://docs.flutter.dev/get-started/fwe/networking',
#  'https://docs.flutter.dev/get-started/install',
#  'https://docs.flutter.dev/get-started/install/chromeos',
#  'https://docs.flutter.dev/get-started/install/help',
#  'https://docs.flutter.dev/get-started/install/linux',
#  'https://docs.flutter.dev/get-started/install/macos',
#  'https://docs.flutter.dev/get-started/install/macos/desktop',
#  'https://docs.flutter.dev/get-started/install/macos/mobile-android',
#  'https://docs.flutter.dev/get-started/install/macos/mobile-ios',
#  'https://docs.flutter.dev/get-started/install/macos/web',
#  'https://docs.flutter.dev/get-started/install/windows',
#  'https://docs.flutter.dev/get-started/install/windows/desktop',
#  'https://docs.flutter.dev/get-started/install/windows/mobile',
#  'https://docs.flutter.dev/get-started/install/windows/web',
#  'https://docs.flutter.dev/get-started/learn-more',
#  'https://docs.flutter.dev/get-started/test-drive',
#  'https://docs.flutter.dev/get-started/uninstall',
#  'https://docs.flutter.dev/jobs',
#  'https://docs.flutter.dev/packages-and-plugins',
#  'https://docs.flutter.dev/packages-and-plugins/background-processes',
#  'https://docs.flutter.dev/packages-and-plugins/developing-packages',
#  'https://docs.flutter.dev/packages-and-plugins/favorites',
#  'https://docs.flutter.dev/packages-and-plugins/using-packages',
#  'https://docs.flutter.dev/perf',
#  'https://docs.flutter.dev/perf/app-size',
#  'https://docs.flutter.dev/perf/appendix',
#  'https://docs.flutter.dev/perf/best-practices',
#  'https://docs.flutter.dev/perf/deferred-components',
#  'https://docs.flutter.dev/perf/faq',
#  'https://docs.flutter.dev/perf/impeller',
#  'https://docs.flutter.dev/perf/isolates',
#  'https://docs.flutter.dev/perf/metrics',
#  'https://docs.flutter.dev/perf/rendering-performance',
#  'https://docs.flutter.dev/perf/shader',
#  'https://docs.flutter.dev/perf/ui-performance',
#  'https://docs.flutter.dev/perf/web-performance',
#  'https://docs.flutter.dev/platform-integration',
#  'https://docs.flutter.dev/platform-integration/android',
#  'https://docs.flutter.dev/platform-integration/android/c-interop',
#  'https://docs.flutter.dev/platform-integration/android/chromeos',
#  'https://docs.flutter.dev/platform-integration/android/platform-views',
#  'https://docs.flutter.dev/platform-integration/android/restore-state-android',
#  'https://docs.flutter.dev/platform-integration/android/splash-screen',
#  'https://docs.flutter.dev/platform-integration/desktop',
#  'https://docs.flutter.dev/platform-integration/ios',
#  'https://docs.flutter.dev/platform-integration/ios/app-extensions',
#  'https://docs.flutter.dev/platform-integration/ios/apple-frameworks',
#  'https://docs.flutter.dev/platform-integration/ios/c-interop',
#  'https://docs.flutter.dev/platform-integration/ios/ios-app-clip',
#  'https://docs.flutter.dev/platform-integration/ios/ios-debugging',
#  'https://docs.flutter.dev/platform-integration/ios/launch-screen',
#  'https://docs.flutter.dev/platform-integration/ios/platform-views',
#  'https://docs.flutter.dev/platform-integration/ios/restore-state-ios',
#  'https://docs.flutter.dev/platform-integration/linux',
#  'https://docs.flutter.dev/platform-integration/linux/building',
#  'https://docs.flutter.dev/platform-integration/macos',
#  'https://docs.flutter.dev/platform-integration/macos/building',
#  'https://docs.flutter.dev/platform-integration/macos/c-interop',
#  'https://docs.flutter.dev/platform-integration/platform-adaptations',
#  'https://docs.flutter.dev/platform-integration/platform-channels',
#  'https://docs.flutter.dev/platform-integration/web',
#  'https://docs.flutter.dev/platform-integration/web/building',
#  'https://docs.flutter.dev/platform-integration/web/faq',
#  'https://docs.flutter.dev/platform-integration/web/initialization',
#  'https://docs.flutter.dev/platform-integration/web/renderers',
#  'https://docs.flutter.dev/platform-integration/web/wasm',
#  'https://docs.flutter.dev/platform-integration/web/web-images',
#  'https://docs.flutter.dev/platform-integration/windows',
#  'https://docs.flutter.dev/platform-integration/windows/building',
#  'https://docs.flutter.dev/platform-integration/windows/extern_win',
#  'https://docs.flutter.dev/reference/crash-reporting',
#  'https://docs.flutter.dev/reference/flutter-cli',
#  'https://docs.flutter.dev/reference/security-false-positives',
#  'https://docs.flutter.dev/reference/supported-platforms',
#  'https://docs.flutter.dev/reference/tutorials',
#  'https://docs.flutter.dev/reference/user-surveys',
#  'https://docs.flutter.dev/reference/widgets',
#  'https://docs.flutter.dev/release/archive-whats-new',
#  'https://docs.flutter.dev/release/archive',
#  'https://docs.flutter.dev/release/breaking-changes',
#  'https://docs.flutter.dev/release/breaking-changes/1-22-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/2-10-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/2-2-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/2-5-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/3-10-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/3-13-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/3-16-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/3-3-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/3-7-deprecations',
#  'https://docs.flutter.dev/release/breaking-changes/actions-api-revision',
#  'https://docs.flutter.dev/release/breaking-changes/add-applifecyclestate-hidden',
#  'https://docs.flutter.dev/release/breaking-changes/add-currentAutofillScope-to-TextInputClient',
#  'https://docs.flutter.dev/release/breaking-changes/add-showAutocorrectionPromptRect',
#  'https://docs.flutter.dev/release/breaking-changes/android-14-nonlinear-text-scaling-migration',
#  'https://docs.flutter.dev/release/breaking-changes/android-activity-control-surface-attach',
#  'https://docs.flutter.dev/release/breaking-changes/android-java-gradle-migration-guide',
#  'https://docs.flutter.dev/release/breaking-changes/android-predictive-back',
#  'https://docs.flutter.dev/release/breaking-changes/android-setIsRunningInRobolectricTest-removed',
#  'https://docs.flutter.dev/release/breaking-changes/android-v1-embedding-create-deprecation',
#  'https://docs.flutter.dev/release/breaking-changes/androidx-migration',
#  'https://docs.flutter.dev/release/breaking-changes/animation-sheet-builder-display',
#  'https://docs.flutter.dev/release/breaking-changes/annotations-return-local-position-relative-to-object',
#  'https://docs.flutter.dev/release/breaking-changes/asset-manifest-dot-json',
#  'https://docs.flutter.dev/release/breaking-changes/bottom-navigation-title-to-label',
#  'https://docs.flutter.dev/release/breaking-changes/buildtextspan-buildcontext',
#  'https://docs.flutter.dev/release/breaking-changes/buttons',
#  'https://docs.flutter.dev/release/breaking-changes/can-request-focus',
#  'https://docs.flutter.dev/release/breaking-changes/checkbox-fillColor',
#  'https://docs.flutter.dev/release/breaking-changes/chip-usedeletebuttontooltip-migration',
#  'https://docs.flutter.dev/release/breaking-changes/clip-behavior',
#  'https://docs.flutter.dev/release/breaking-changes/clipboard-data-required',
#  'https://docs.flutter.dev/release/breaking-changes/container-color',
#  'https://docs.flutter.dev/release/breaking-changes/context-menus',
#  'https://docs.flutter.dev/release/breaking-changes/cupertino-icons-1.0.0',
#  'https://docs.flutter.dev/release/breaking-changes/cupertino-tab-bar-localizations',
#  'https://docs.flutter.dev/release/breaking-changes/default-desktop-scrollbars',
#  'https://docs.flutter.dev/release/breaking-changes/default-scroll-behavior-drag',
#  'https://docs.flutter.dev/release/breaking-changes/deprecate-textscalefactor',
#  'https://docs.flutter.dev/release/breaking-changes/describe-enum',
#  'https://docs.flutter.dev/release/breaking-changes/dialog-border-radius',
#  'https://docs.flutter.dev/release/breaking-changes/dispose',
#  'https://docs.flutter.dev/release/breaking-changes/editable-text-focus-attachment',
#  'https://docs.flutter.dev/release/breaking-changes/editable-text-scroll-into-view',
#  'https://docs.flutter.dev/release/breaking-changes/eliminating-nullok-parameters',
#  'https://docs.flutter.dev/release/breaking-changes/enterText-trailing-caret',
#  'https://docs.flutter.dev/release/breaking-changes/fab-theme-data-accent-properties',
#  'https://docs.flutter.dev/release/breaking-changes/flutter-driver-migration',
#  'https://docs.flutter.dev/release/breaking-changes/flutter-gradle-plugin-apply',
#  'https://docs.flutter.dev/release/breaking-changes/flutter-lints-package',
#  'https://docs.flutter.dev/release/breaking-changes/flutter-memory-allocations',
#  'https://docs.flutter.dev/release/breaking-changes/forgetchild-call-super',
#  'https://docs.flutter.dev/release/breaking-changes/form-field-autovalidation-api',
#  'https://docs.flutter.dev/release/breaking-changes/gesture-recognizer-add-allowed-pointer',
#  'https://docs.flutter.dev/release/breaking-changes/hero-controller-scope',
#  'https://docs.flutter.dev/release/breaking-changes/ignoringsemantics-migration',
#  'https://docs.flutter.dev/release/breaking-changes/image-cache-and-provider',
#  'https://docs.flutter.dev/release/breaking-changes/image-provider-load-buffer',
#  'https://docs.flutter.dev/release/breaking-changes/imagecache-large-images',
#  'https://docs.flutter.dev/release/breaking-changes/insert-content-text-input-client',
#  'https://docs.flutter.dev/release/breaking-changes/ios-flutterviewcontroller-splashscreenview-nullable',
#  'https://docs.flutter.dev/release/breaking-changes/key-event-migration',
#  'https://docs.flutter.dev/release/breaking-changes/kotlin-version',
#  'https://docs.flutter.dev/release/breaking-changes/layout-builder-optimization',
#  'https://docs.flutter.dev/release/breaking-changes/material-3-default',
#  'https://docs.flutter.dev/release/breaking-changes/material-3-migration',
#  'https://docs.flutter.dev/release/breaking-changes/material-chip-button-semantics',
#  'https://docs.flutter.dev/release/breaking-changes/material-localized-strings',
#  'https://docs.flutter.dev/release/breaking-changes/menus-text-style',
#  'https://docs.flutter.dev/release/breaking-changes/mock-platform-channels',
#  'https://docs.flutter.dev/release/breaking-changes/modal-router-semantics-order',
#  'https://docs.flutter.dev/release/breaking-changes/mouse-tracker-moved-to-rendering',
#  'https://docs.flutter.dev/release/breaking-changes/mouse-tracker-no-longer-attaches-annotations',
#  'https://docs.flutter.dev/release/breaking-changes/multi-touch-scrolling',
#  'https://docs.flutter.dev/release/breaking-changes/network-policy-ios-android',
#  'https://docs.flutter.dev/release/breaking-changes/notifications',
#  'https://docs.flutter.dev/release/breaking-changes/nullable-cupertinothemedata-brightness',
#  'https://docs.flutter.dev/release/breaking-changes/overlay-entry-rebuilds',
#  'https://docs.flutter.dev/release/breaking-changes/page-transition-replaced-by-ZoomPageTransitionBuilder',
#  'https://docs.flutter.dev/release/breaking-changes/pageview-controller',
#  'https://docs.flutter.dev/release/breaking-changes/paint-enableDithering',
#  'https://docs.flutter.dev/release/breaking-changes/parent-data-widget-generic-type',
#  'https://docs.flutter.dev/release/breaking-changes/platform-views-using-html-slots-web',
#  'https://docs.flutter.dev/release/breaking-changes/plugin-api-migration',
#  'https://docs.flutter.dev/release/breaking-changes/primary-scroll-controller-desktop',
#  'https://docs.flutter.dev/release/breaking-changes/raw-images-on-web-uses-correct-origin-and-colors',
#  'https://docs.flutter.dev/release/breaking-changes/renderbox-dry-layout',
#  'https://docs.flutter.dev/release/breaking-changes/rendereditable-layout-before-hit-test',
#  'https://docs.flutter.dev/release/breaking-changes/rendering-changes',
#  'https://docs.flutter.dev/release/breaking-changes/route-information-uri',
#  'https://docs.flutter.dev/release/breaking-changes/route-navigator-refactoring',
#  'https://docs.flutter.dev/release/breaking-changes/route-transition-record-and-transition-delegate',
#  'https://docs.flutter.dev/release/breaking-changes/routesettings-copywith-migration',
#  'https://docs.flutter.dev/release/breaking-changes/scaffold-messenger',
#  'https://docs.flutter.dev/release/breaking-changes/scribble-text-input-client',
#  'https://docs.flutter.dev/release/breaking-changes/scrollable-alert-dialog',
#  'https://docs.flutter.dev/release/breaking-changes/services-scheduler-dependency-reversed',
#  'https://docs.flutter.dev/release/breaking-changes/shortcut-key-event-migration',
#  'https://docs.flutter.dev/release/breaking-changes/splash-screen-migration',
#  'https://docs.flutter.dev/release/breaking-changes/supplemental-maybeOf-migration',
#  'https://docs.flutter.dev/release/breaking-changes/tab-alignment',
#  'https://docs.flutter.dev/release/breaking-changes/target-platform-linux-windows',
#  'https://docs.flutter.dev/release/breaking-changes/template',
#  'https://docs.flutter.dev/release/breaking-changes/test-text-input',
#  'https://docs.flutter.dev/release/breaking-changes/test-widgets-flutter-binding-clock',
#  'https://docs.flutter.dev/release/breaking-changes/text-field-material-localizations',
#  'https://docs.flutter.dev/release/breaking-changes/text-input-client-current-value',
#  'https://docs.flutter.dev/release/breaking-changes/text-selection-theme',
#  'https://docs.flutter.dev/release/breaking-changes/theme-data-accent-properties',
#  'https://docs.flutter.dev/release/breaking-changes/toggleable-active-color',
#  'https://docs.flutter.dev/release/breaking-changes/tooltip-semantics-order',
#  'https://docs.flutter.dev/release/breaking-changes/trackpad-gestures',
#  'https://docs.flutter.dev/release/breaking-changes/use-maxLengthEnforcement-instead-of-maxLengthEnforced',
#  'https://docs.flutter.dev/release/breaking-changes/win-lifecycle-process-function',
#  'https://docs.flutter.dev/release/breaking-changes/window-singleton',
#  'https://docs.flutter.dev/release/breaking-changes/windows-build-architecture',
#  'https://docs.flutter.dev/release/breaking-changes/windows-dark-mode',
#  'https://docs.flutter.dev/release/breaking-changes/windows-run-loop',
#  'https://docs.flutter.dev/release/breaking-changes/windows-show-window-migration',
#  'https://docs.flutter.dev/release/breaking-changes/windows-version-information',
#  'https://docs.flutter.dev/release/breaking-changes/zone-errors',
#  'https://docs.flutter.dev/release/compatibility-policy',
#  'https://docs.flutter.dev/release/release-notes',
#  'https://docs.flutter.dev/release/release-notes/changelogs/changelog-1.12.13',
#  'https://docs.flutter.dev/release/release-notes/changelogs/changelog-1.2.1',
#  'https://docs.flutter.dev/release/release-notes/changelogs/changelog-1.5.4',
#  'https://docs.flutter.dev/release/release-notes/changelogs/changelog-1.7.8',
#  'https://docs.flutter.dev/release/release-notes/changelogs/changelog-1.9.1',
#  'https://docs.flutter.dev/release/release-notes/release-notes-0.0.21-1.0.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.12.13',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.17.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.2.1',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.20.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.22.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.5.4',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.7.8',
#  'https://docs.flutter.dev/release/release-notes/release-notes-1.9.1',
#  'https://docs.flutter.dev/release/release-notes/release-notes-2.0.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-2.10.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-2.2.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-2.5.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-2.8.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.0.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.10.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.13.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.16.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.19.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.3.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-3.7.0',
#  'https://docs.flutter.dev/release/release-notes/release-notes-archive',
#  'https://docs.flutter.dev/release/upgrade',
#  'https://docs.flutter.dev/release/whats-new',
#  'https://docs.flutter.dev/resources/architectural-overview',
#  'https://docs.flutter.dev/resources/books',
#  'https://docs.flutter.dev/resources/bootstrap-into-dart',
#  'https://docs.flutter.dev/resources/bug-reports',
#  'https://docs.flutter.dev/resources/courses',
#  'https://docs.flutter.dev/resources/faq',
#  'https://docs.flutter.dev/resources/games-toolkit',
#  'https://docs.flutter.dev/resources/inside-flutter',
#  'https://docs.flutter.dev/resources/news-toolkit',
#  'https://docs.flutter.dev/resources/videos',
#  'https://docs.flutter.dev/search-all',
#  'https://docs.flutter.dev/search',
#  'https://docs.flutter.dev/security',
#  'https://docs.flutter.dev/testing',
#  'https://docs.flutter.dev/testing/build-modes',
#  'https://docs.flutter.dev/testing/code-debugging',
#  'https://docs.flutter.dev/testing/common-errors',
#  'https://docs.flutter.dev/testing/debugging',
#  'https://docs.flutter.dev/testing/errors',
#  'https://docs.flutter.dev/testing/integration-tests',
#  'https://docs.flutter.dev/testing/native-debugging',
#  'https://docs.flutter.dev/testing/overview',
#  'https://docs.flutter.dev/testing/plugins-in-tests',
#  'https://docs.flutter.dev/testing/testing-plugins',
#  'https://docs.flutter.dev/tools',
#  'https://docs.flutter.dev/tools/android-studio',
#  'https://docs.flutter.dev/tools/devtools',
#  'https://docs.flutter.dev/tools/devtools/android-studio',
#  'https://docs.flutter.dev/tools/devtools/app-size',
#  'https://docs.flutter.dev/tools/devtools/cli',
#  'https://docs.flutter.dev/tools/devtools/console',
#  'https://docs.flutter.dev/tools/devtools/cpu-profiler',
#  'https://docs.flutter.dev/tools/devtools/debugger',
#  'https://docs.flutter.dev/tools/devtools/extensions',
#  'https://docs.flutter.dev/tools/devtools/inspector',
#  'https://docs.flutter.dev/tools/devtools/logging',
#  'https://docs.flutter.dev/tools/devtools/memory',
#  'https://docs.flutter.dev/tools/devtools/network',
#  'https://docs.flutter.dev/tools/devtools/overview',
#  'https://docs.flutter.dev/tools/devtools/performance',
#  'https://docs.flutter.dev/tools/devtools/release-notes',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.10.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.11.2',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.12.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.12.2',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.13.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.14.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.15.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.16.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.17.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.18.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.19.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.20.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.21.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.22.2',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.23.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.24.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.25.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.26.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.27.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.28.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.28.2',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.28.3',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.28.4',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.28.5',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.29.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.30.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.31.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.32.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.7.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.8.0',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.9.1',
#  'https://docs.flutter.dev/tools/devtools/release-notes/release-notes-2.9.2',
#  'https://docs.flutter.dev/tools/devtools/vscode',
#  'https://docs.flutter.dev/tools/flutter-fix',
#  'https://docs.flutter.dev/tools/formatting',
#  'https://docs.flutter.dev/tools/hot-reload',
#  'https://docs.flutter.dev/tools/pubspec',
#  'https://docs.flutter.dev/tools/sdk',
#  'https://docs.flutter.dev/tools/vs-code',
#  'https://docs.flutter.dev/tos',
#  'https://docs.flutter.dev/ui',
#  'https://docs.flutter.dev/ui/accessibility-and-internationalization',
#  'https://docs.flutter.dev/ui/accessibility-and-internationalization/accessibility',
#  'https://docs.flutter.dev/ui/accessibility-and-internationalization/internationalization',
#  'https://docs.flutter.dev/ui/animations',
#  'https://docs.flutter.dev/ui/animations/hero-animations',
#  'https://docs.flutter.dev/ui/animations/implicit-animations',
#  'https://docs.flutter.dev/ui/animations/overview',
#  'https://docs.flutter.dev/ui/animations/staggered-animations',
#  'https://docs.flutter.dev/ui/animations/tutorial',
#  'https://docs.flutter.dev/ui/assets',
#  'https://docs.flutter.dev/ui/assets/assets-and-images',
#  'https://docs.flutter.dev/ui/design/graphics/fragment-shaders',
#  'https://docs.flutter.dev/ui/design/material',
#  'https://docs.flutter.dev/ui/design/text/typography',
#  'https://docs.flutter.dev/ui/interactivity',
#  'https://docs.flutter.dev/ui/interactivity/actions-and-shortcuts',
#  'https://docs.flutter.dev/ui/interactivity/focus',
#  'https://docs.flutter.dev/ui/interactivity/gestures',
#  'https://docs.flutter.dev/ui/interactivity/gestures/drag-outside',
#  'https://docs.flutter.dev/ui/layout',
#  'https://docs.flutter.dev/ui/layout/constraints',
#  'https://docs.flutter.dev/ui/layout/responsive/adaptive-responsive',
#  'https://docs.flutter.dev/ui/layout/responsive/building-adaptive-apps',
#  'https://docs.flutter.dev/ui/layout/scrolling',
#  'https://docs.flutter.dev/ui/layout/scrolling/slivers',
#  'https://docs.flutter.dev/ui/layout/tutorial',
#  'https://docs.flutter.dev/ui/navigation',
#  'https://docs.flutter.dev/ui/navigation/deep-linking',
#  'https://docs.flutter.dev/ui/navigation/url-strategies',
#  'https://docs.flutter.dev/ui/widgets',
#  'https://docs.flutter.dev/ui/widgets/accessibility',
#  'https://docs.flutter.dev/ui/widgets/animation',
#  'https://docs.flutter.dev/ui/widgets/assets',
#  'https://docs.flutter.dev/ui/widgets/async',
#  'https://docs.flutter.dev/ui/widgets/basics',
#  'https://docs.flutter.dev/ui/widgets/cupertino',
#  'https://docs.flutter.dev/ui/widgets/input',
#  'https://docs.flutter.dev/ui/widgets/interaction',
#  'https://docs.flutter.dev/ui/widgets/layout',
#  'https://docs.flutter.dev/ui/widgets/material',
#  'https://docs.flutter.dev/ui/widgets/material2',
#  'https://docs.flutter.dev/ui/widgets/painting',
#  'https://docs.flutter.dev/ui/widgets/scrolling',
#  'https://docs.flutter.dev/ui/widgets/styling',
#  'https://docs.flutter.dev/ui/widgets/text']

# %%
len(sites_filtered)
# Out:
# 503

# %%
sites_filtered[100]
# Out:
# 'https://docs.flutter.dev/cookbook/testing/unit/introduction'

# %% [markdown]
# ## Load page content using LangChains UnstructuredURLLoader

# %%
from langchain.document_loaders import UnstructuredURLLoader
loader = UnstructuredURLLoader(urls=sites_filtered)
documents = loader.load()
len(documents)

# %%
documents[100]

# %% [markdown]
# ## Chunking

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 2000,
    chunk_overlap  = 200)

document_chunks = text_splitter.split_documents(documents)

print(f"Number documents {len(documents)}")
print(f"Number chunks {len(document_chunks)}")
# Out:
# Created a chunk of size 2041, which is longer than the specified 2000
# Created a chunk of size 5157, which is longer than the specified 2000
# Created a chunk of size 2192, which is longer than the specified 2000
# Number documents 502
# Number chunks 5431

# %%
document_chunks[100]
# Out:
# Document(page_content='The Theme.of(context) method looks up the widget tree and retrieves\nthe nearest Theme in the tree.\nIf you have a standalone Theme, that’s applied.\nIf not, Flutter applies the app’s theme.\nIn the following example, the Container constructor uses this technique to set its color.\nOverride a theme\nTo override the overall theme in part of an app,\nwrap that section of the app in a Theme widget.\nYou can override a theme in two ways:\nCreate a unique ThemeData instance.\nExtend the parent theme.\nSet a unique ThemeData instance\nIf you want a component of your app to ignore the overall theme,\ncreate a ThemeData instance.\nPass that instance to the Theme widget.\nExtend the parent theme\nInstead of overriding everything, consider extending the parent theme.\nTo extend a theme, use the copyWith() method.\nWatch a video on Theme\nTo learn more, watch this short Widget of the Week video on the Theme widget:\nTry an interactive example', metadata={'source': 'https://docs.flutter.dev/cookbook/design/themes'})

# %% [markdown]
# # Embeddings for documents

# %% [markdown]
# ## Create embedding for all document chunks

# %%
store.add_documents(documents=document_chunks, embedding=embedding)
# Out:
# ['6a19df18ae734887b66a42221e107535',
#  '8c5df770dedd43629d92a09392019080',
#  'd20f2502bcba4d01b28de4b0e665eb57',
#  '6280ff59b1b842a89b07fd2995ed4266',
#  '0fb6b07ea6024dcaa0101fd7d46f3edd',
#  'e8f9ed01a488443087968d74cc06ee1d',
#  'a8c164f2a478457d8f33f930b83603f7',
#  '3c1aac884354473091d9497675e76498',
#  'f44202ec78e34ea18fe4a078f3e48e34',
#  '276509762bc643f393f8a26a32dcf6b3',
#  '355e24a14f784d008f0040459ba5b14a',
#  '2d281fb729454624aa4179c23c28bf62',
#  '6379171554f241d2901d04659e0f2197',
#  'b5c86370393549769a781f1156412c3d',
#  '7994826de00345f9a3842f67413dc440',
#  '23cf5d43eeca4ddcb99bf690589ca5c2',
#  '825c925d5e44414a9ebcfe0ad4e26be3',
#  '72671336854d4b9396cce2e6faa09b78',
#  '7692a64f265e4cbd90479aa84b097c03',
#  'c7e06d8a08cc44cab791aaa13ca2b887',
#  'c3b20938a6a6423b8bde9581b106a7cc',
#  '1e6e5b1cce5844d88bf0d29ad2067f81',
#  '7556d9c1a82d44368064b6c2fa86ba4e',
#  '3b818fdb84a247a98ae31fb446cf1477',
#  '43811eedc3904ddd889c6f81fd3941c5',
#  '4549a097163b46818159d5d12cd99d5b',
#  'afd832b9dbb546319cfa8d5b8a132eb9',
#  '83eb8ec45651414bbcd083e7391e7476',
#  'c3729de97c1743eb993bbc9a3adeba22',
#  'eb237db204c24bd8adbc65ee988f4fb5',
#  'c097c101ed764a369893e56836ad8dc1',
#  '622a528c43de4626b48ccbfc199d6957',
#  'a05be1f1d91e477ca2fada06ddf8c0ed',
#  '6bf34dcd74da48bd9779db281577c15a',
#  'cad8561cda6049f0b506a8a379d2f71a',
#  'eb0580c5685a43428180045449526183',
#  '9e9c36d556654fa99ac6bf2a2fdaf2c1',
#  '72507b67b5ed4be6a9372dc3d8353288',
#  'daf0678a8be64a1dbe3522bd32d7acde',
#  '45df0813c0d047328e69a24067a5235f',
#  'ae46b27d425247d6880bb41ac88e9229',
#  '300bf226f62f4dbe925e2393efa5cf0c',
#  '5f23fa0b79624675ba13a178d0185ee3',
#  '5b3844c3fb4049ae83c7022e192a8924',
#  'dd2af7cf3d204d4e8fbcc35893764e35',
#  'daa07d1caefd41c3875dd606d1c86279',
#  '478b4a4159c54a7c8be5932b6d93743b',
#  'f277e943f2894f5aae4da8e42c068ce4',
#  'ccb895b9dec647e4b18ef92676155e1f',
#  'd13b756d45f040aaabbcb3d535f6e191',
#  '376bfb61dace4ecfb4ad28d7b87cdc16',
#  'bfcecaf17bf44dfa8d1c45bd5ac0f5e1',
#  '5fbfba4771cd42868d7179b627e744d9',
#  '0b971e42fd6340e0959f87912a9481f9',
#  'caf3185c416e4cd6983d17b2a5cbc2d4',
#  'c85df7b64e744dd0b8e0974edf329796',
#  'd37da597230b4e9b9178dad00bf22bb7',
#  '15b4d83546a64093b353268fd42363ef',
#  'b0201ce786c04bf59e94942d4aa091f5',
#  'a96967ca4d4449d1b1e3eae232b0c9e0',
#  'c7355339cb854020afc558a85c7409c7',
#  '5559065bffe54b84a8e625654de62412',
#  '6c32179a26ec4ce8a8a8496650086ac2',
#  '52a470117adc4852a119c22477ce281b',
#  'e62fc6bc865444b88d04f99ff2dd1790',
#  'cd4bf982fd8b47cf86d0554f84f217b8',
#  '96744d30eec9498c9485efbafaed546c',
#  'e622241f0f41403db7552b4c41c701d7',
#  '06f856dea4474725b0f093f510e271bb',
#  '6369e2c224aa41af8dadecebbaf33b82',
#  'f717cdc4b7864fe7bcd7a72009ee55a7',
#  'f11ca9e4cc2b4d13adaa5e361b0142b5',
#  '925266616d6d4eae8944ab23254f614c',
#  '09cb2b0fe320464ab315dcf15bcbe531',
#  '4a59ffd6e1614efcbd89f0451ad0f0ac',
#  '45728f0f79ea40909a08467b218440da',
#  'cbaf2b6737034eecaed09274089dae5c',
#  '171559ce26cf40019f0ba9c334442bc2',
#  '71a71d205f754ca08965219e9168f738',
#  '7789f6ef8b14450cb7b1620f88167f63',
#  '2b4e160f792d403fa95db5c8786eab41',
#  '68f32f39def04d609a1964ed5b01ec5d',
#  'ad744cdd103940c79555eb8fcee8b3d2',
#  'ce891779c94e4bbaa7a36ca34159ecf1',
#  '12ef9ae9238540cf8bad254af08d8b77',
#  'ac73c95770ee4a6a85476b350c23e4d4',
#  'b147d0c8fb1a457d998b92b6fdec8ffe',
#  '24c32829872c4d328f25f4164dfa2fce',
#  'd78a485e8b8143cbb43fdfecfb3d137e',
#  'a97486f31b974717abbc67f49ecb85ab',
#  '17a100ac31f44a59a8782f4e9c5a6798',
#  '03ce1a06ae944eb6ae5c7476830fd9a5',
#  '6916538636ec41bdba40f80e98b2a78f',
#  '84e290feb5764c42ba8294056dad5234',
#  '254d1b05526c4ad69a022351487d6b6f',
#  'a4e5031ce6764b8592b83698e4ccf02e',
#  'f3e282a0229e4361ad80e9b9671050d5',
#  '6543a00728b94da88a218f52dfd12a9f',
#  '572148c429884411b0f2ab73e50e4aeb',
#  '114b704302a343399e4c475b1157efdb',
#  '47299f2b442345dca264337fd21025e8',
#  '5ffa488013ed4d68a2914e021b001d68',
#  '7d6bbf0cbe234dc5b267b174aa1a1d8b',
#  'ffd682ebc8154b408b18dc385b6770f4',
#  '5951726efb554061a8273929507dec78',
#  '8771b78ae13947e7b9acab90159a9960',
#  '379101ccdae84442932b8c1dcda0c079',
#  '92f4f13701bb4330951b6cdb11175798',
#  ...]

# %%
question = "What is Flutter?"

# %%
store.similarity_search(question, k=8)
# Out:
# [Document(page_content='It speeds app development and reduces the cost and complexity\nof app production across platforms.\nFor designers, Flutter provides a canvas for\nhigh-end user experiences. Fast Company described\nFlutter as one of the top design ideas of the decade for\nits ability to turn concepts into production code\nwithout the compromises imposed by typical frameworks.\nIt also acts as a productive prototyping tool\nwith drag-and-drop tools like FlutterFlow\nand web-based IDEs like Zapp!.\nFor engineering managers and businesses,\nFlutter allows the unification of app\ndevelopers into a single mobile, web,\nand desktop app team, building branded\napps for multiple platforms out of a single codebase.\nFlutter speeds feature development and synchronizes\nrelease schedules across the entire customer base.\nHow much development experience do I need to use Flutter?\nFlutter is approachable to programmers familiar with\nobject-oriented concepts (classes, methods, variables,\netc) and imperative programming concepts (loops,\nconditionals, etc).\nWe have seen people with very little programming\nexperience learn and use Flutter for prototyping\nand app development.\nWhat kinds of apps can I build with Flutter?\nFlutter is designed to support mobile apps that run\non both Android and iOS, as well as interactive apps\nthat you want to run on your web pages or on the desktop.\nApps that need to deliver highly branded designs\nare particularly well suited for Flutter.\nHowever, you can also create pixel-perfect experiences\nthat match the Android and iOS design languages with Flutter.\nFlutter’s package ecosystem supports a wide\nvariety of hardware (such as camera, GPS, network,\nand storage) and services (such as payments, cloud\nstorage, authentication, and ads).\nWho makes Flutter?\nFlutter is an open source project,\nwith contributions from Google and other\ncompanies and individuals.\nWho uses Flutter?\nDevelopers inside and outside of Google use\nFlutter to build beautiful natively-compiled', metadata={'source': 'https://docs.flutter.dev/resources/faq', '__id': '6f1e5027cd35480ba75ca0f108943003', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='Why would I want to share layout code across iOS and Android?\nCan I interop with my mobile platform’s default programming language?\nDoes Flutter come with a reflection / mirrors system?\nHow do I do international\xadization (i18n), localization (l10n), and accessibility (a11y) in Flutter?\nHow do I write parallel and/or concurrent apps for Flutter?\nCan I run Dart code in the background of a Flutter app?\nCan I use JSON/XML/protobuffers (and so on) with Flutter?\nCan I build 3D (OpenGL) apps with Flutter?\nWhy is my APK or IPA so big?\nDo Flutter apps run on Chromebooks?\nIs Flutter ABI compatible?\nFramework\nWhy is the build() method on State, rather than StatefulWidget?\nWhere is Flutter’s markup language? Why doesn’t Flutter have a markup syntax?\nMy app has a Debug banner/ribbon in the upper right. Why am I seeing that?\nWhat programming paradigm does Flutter’s framework use?\nProject\nWhere can I get support?\nHow do I get involved?\nIs Flutter open source?\nWhich software license(s) apply to Flutter and its dependencies?\nHow can I determine the licenses my Flutter application needs to show?\nWho works on Flutter?\nWhat are Flutter’s guiding principles?\nWill Apple reject my Flutter app?\nIntroduction\nThis page collects some common questions asked about\nFlutter. You might also check out the following\nspecialized FAQs:\nWeb FAQ\nPerformance FAQ\nWhat is Flutter?\nFlutter is Google’s portable UI toolkit for crafting beautiful,\nnatively compiled applications for mobile, web,\nand desktop from a single codebase.\nFlutter works with existing code,\nis used by developers and organizations around\nthe world, and is free and open source.\nWho is Flutter for?\nFor users, Flutter makes beautiful apps come to life.\nFor developers, Flutter lowers the bar to entry for building apps.\nIt speeds app development and reduces the cost and complexity\nof app production across platforms.\nFor designers, Flutter provides a canvas for\nhigh-end user experiences. Fast Company described', metadata={'source': 'https://docs.flutter.dev/resources/faq', '__id': '17af91c386764d94960496d5a1c504fe', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='can access a remote widget’s state in a type-safe manner\n(using runtime checking), the Route interface is\nparameterized with the type that it is expected to use when\npopped, and collections such as Lists, Maps,\nand Sets are all parameterized so that mismatched\nelements can be caught early either during analysis or at\nruntime during debugging.\nFlutter makes heavy use of Futures and other\nasynchronous APIs. For example, the animation system reports\nwhen an animation is finished by completing a future.\nThe image loading system similarly uses futures to report\nwhen a load is complete.\nThe layout system in Flutter uses a weak form of\nconstraint programming to determine the geometry of a scene.\nConstraints (for example, for cartesian boxes, a minimum and\nmaximum width and a minimum and maximum height)\nare passed from parent to child, and the child selects a resulting\ngeometry (for example, for cartesian boxes, a size,\nspecifically a width and a height) that fulfills those constraints.\nBy using this technique, Flutter can usually\nlay out an entire scene with a single pass.\nProject\nWhere can I get support?\nIf you think you’ve encountered a bug, file it in our\nissue tracker. You might also use\nStack Overflow for “HOWTO” type questions.\nFor discussions, join our mailing list at\nflutter-dev@googlegroups.com or seek us out on Discord.\nFor more information, see our Community page.\nHow do I get involved?\nFlutter is open source, and we encourage you to contribute.\nYou can start by simply filing issues for feature requests\nand bugs in our issue tracker.\nWe recommend that you join our mailing list at\nflutter-dev@googlegroups.com and let us know how you’re\nusing Flutter and what you’d like to do with it.\nIf you’re interested in contributing code, you can start\nby reading our Contributing guide, and check out our\nlist of easy starter issues.\nFinally, you can connect with helpful Flutter communities.\nFor more information, see the Community page.\nIs Flutter open source?', metadata={'source': 'https://docs.flutter.dev/resources/faq', '__id': '74629672d52a4431ba99e60e729fb94d', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='Build an event RSVP and guestbook chat app on both Android\nand iOS using Flutter, authenticating users with Firebase\nAuthentication, and sync data using Cloud Firestore.\nLocal development for your Flutter apps using the Firebase Emulator Suite\nLearn how to use the Firebase Emulator Suite when\ndeveloping with Flutter. You will also learn to use\nthe Auth and Firestore emulators.\nFlutter and TensorFlow\nCreate a custom text-classification model with TensorFlow Lite Model Maker\nCreate a Flutter app to classify texts with TensorFlow\nLearn how to run a text-classification inference from a Flutter\napp with TensorFlow Serving through REST and gRPC.\nTrain a comment-spam detection model with TensorFlow Lite Model Maker\nLearn how to install the TensorFlow Lite Model Maker with Colab,\nhow to use a data loader, and how to build a model.\nFlutter and other technologies\nAdding Google Maps to a Flutter app\nDisplay a Google map in an app, retrieve data from a\nweb service, and display the data as markers on the map.\nAdding WebView to your Flutter app\nWith the WebView Flutter plugin you can add a WebView\nwidget to your Android or iOS Flutter app.\nBuild voice bots for mobile with Dialogflow and Flutter (workshop)\nAn instructor-led version of the Dialogflow\nand Flutter codelab (listed below).\nBuild voice bots for Android with Dialogflow and Flutter\nLearn how to build a mobile FAQ bot that can answer most\ncommon questions about the tool Dialogflow. End users\ncan interact with the text interface or stream a voice\ninteraction via the built-in microphone of a mobile device.\nIntroduction to Flame with Flutter\nBuild a Breakout clone using the Flame 2D game engine and\nembed it in a Flutter wrapper. You will use Flame’s Effects\nto animate and remove components, along with the google_fonts and\nflutter_animate packages, to make the whole game look well designed.\nUsing FFI in a Flutter plugin\nLearn how to use Dart’s FFI (foreign function interface)\nlibrary, ffigen, allowing you to leverage', metadata={'source': 'https://docs.flutter.dev/codelabs', '__id': '5e00f9b0b55345899ff04039093471d0', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='Build an event RSVP and guestbook chat app on both Android\nand iOS using Flutter, authenticating users with Firebase\nAuthentication, and sync data using Cloud Firestore.\nLocal development for your Flutter apps using the Firebase Emulator Suite\nLearn how to use the Firebase Emulator Suite when\ndeveloping with Flutter. You will also learn to use\nthe Auth and Firestore emulators.\nFlutter and TensorFlow\nCreate a custom text-classification model with TensorFlow Lite Model Maker\nCreate a Flutter app to classify texts with TensorFlow\nLearn how to run a text-classification inference from a Flutter\napp with TensorFlow Serving through REST and gRPC.\nTrain a comment-spam detection model with TensorFlow Lite Model Maker\nLearn how to install the TensorFlow Lite Model Maker with Colab,\nhow to use a data loader, and how to build a model.\nFlutter and other technologies\nAdding Google Maps to a Flutter app\nDisplay a Google map in an app, retrieve data from a\nweb service, and display the data as markers on the map.\nAdding WebView to your Flutter app\nWith the WebView Flutter plugin you can add a WebView\nwidget to your Android or iOS Flutter app.\nBuild voice bots for mobile with Dialogflow and Flutter (workshop)\nAn instructor-led version of the Dialogflow\nand Flutter codelab (listed below).\nBuild voice bots for Android with Dialogflow and Flutter\nLearn how to build a mobile FAQ bot that can answer most\ncommon questions about the tool Dialogflow. End users\ncan interact with the text interface or stream a voice\ninteraction via the built-in microphone of a mobile device.\nIntroduction to Flame with Flutter\nBuild a Breakout clone using the Flame 2D game engine and\nembed it in a Flutter wrapper. You will use Flame’s Effects\nto animate and remove components, along with the google_fonts and\nflutter_animate packages, to make the whole game look well designed.\nUsing FFI in a Flutter plugin\nLearn how to use Dart’s FFI (foreign function interface)\nlibrary, ffigen, allowing you to leverage', metadata={'source': 'https://docs.flutter.dev/reference/tutorials', '__id': '3e118a8f837d4109831aa666e3e3f206', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='description\nbug_report\nVideos\nSeries\nFlutter Forward\nGet ready for Flutter Forward\nLearning to Fly\nDecoding Flutter\nFlutter widget of the week\nFlutter package of the week\nThe Boring Flutter show\nFlutter at Google I/O 2022\nFlutter Engage 2021\nFlutter in focus\nConference talks\nFlutter developer stories\nThese Flutter videos, produced both internally\nat Google and by the Flutter community,\nmight help if you are a visual learner.\nNote that many people make Flutter videos.\nThis page shows some that we like,\nbut there are many others, including\nsome in different languages.\nSeries\nFlutter Forward\nEven if you couldn’t make it to Nairobi for the in-person\nevent, you can enjoy the content created for Flutter Forward!\nFlutter Forward livestream\nFlutter Forward playlist\nGet ready for Flutter Forward\nFlutter Forward is happening on Jan 25th, in Nairobi, Kenya.\nBefore the event, the Flutter team provided 17 days of Flutter\nfeaturing new content and activities leading up to the event.\nThis playlist contains these and other pre-event videos relating to\nFlutter Forward.\n17 Days of Flutter!\nGet ready for Flutter Forward playlist\nLearning to Fly\ninfo Note:\n  Season 2 of Learning to Fly has been released as part\n  of the 17 Days of Flutter, leading up to the 3.7\n  release! Season 2 centers around creating a platform\n  game, DoodleDash, using the Flame engine.\nFollow along with Khanh’s journey as she learns Flutter.\nFrom ideation down to the moments of confusion,\nlearn alongside her as she asks important questions like:\n“What is the best way to build out a theme? How to approach using fonts?”\nAnd more!\nBuilding my first Flutter app | Learning to Fly\nLearning to Fly playlist\nHere are some of the series offered on the\nflutterdev YouTube channel.\nFor more information, check out all\nof the Flutter channel’s playlists.\nDecoding Flutter\nThis series focuses on tips, tricks, best practices,\nand general advice on getting the most out of Flutter.\nIn the comments section for this series,', metadata={'source': 'https://docs.flutter.dev/resources/videos', '__id': 'e446a3fb90e946e898dd07c76832a4be', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='Decoding Flutter\nThis series focuses on tips, tricks, best practices,\nand general advice on getting the most out of Flutter.\nIn the comments section for this series,\nyou can submit suggestions future episodes.\nIntroducing Decoding Flutter\nDecoding Flutter playlist\nFlutter widget of the week\nDo you have 60 seconds?\nEach one-minute video highlights a Flutter widget.\nIntroducing widget of the week\nFlutter widget of the week playlist\nFlutter package of the week\nIf you have another minute (or two),\neach of these videos highlights a Flutter package.\nflutter_slidable package\nFlutter package of the week playlist\nThe Boring Flutter show\nThis series features Flutter programmers coding,\nunscripted and in real time. Mistakes, solutions\n(some of them correct), and snazzy intro music included.\nIntroducing the Boring Flutter show\nThe Boring Flutter show playlist\nFlutter at Google I/O 2022\nGoogle I/O 2022 is over, but you can still catch\nthe great Flutter content!\nFlutter at Google I/O playlist\nFlutter Engage 2021\nFlutter Engage 2021 was a day-long event that\nofficially launched Flutter 2.\nCheck out the Flutter Engage 2021 highlights reel.\nWatch recordings of the sessions on the Flutter YouTube channel.\nKeynote\nFlutter Engage 2021 playlist\nWatch recordings of the sessions offered by the Flutter community.\nFlutter Engage community talks playlist\nFlutter in focus\nFive-to-ten minute tutorials (more or less) on using Flutter.\nIntroducing Flutter in focus\nFlutter in focus playlist\nConference talks\nHere are a some Flutter talks given at various conferences.\nConference talks playlist\nFlutter developer stories\nVideos showing how various customers, such as Abbey Road Studio, Hamilton,\nand Alibaba, have used Flutter to create beautiful compelling apps with\nmillions of downloads.\nFlutter developer stories playlist', metadata={'source': 'https://docs.flutter.dev/resources/videos', '__id': '0cd5b83a958341d681224058241c0ca0', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'}),
#  Document(page_content='description\nbug_report\nPackages & plugins\nPackages & plugins\nTopics\nUse packages & plugins\nDevelop packages & plugins\nFlutter Favorites\nPackage repository', metadata={'source': 'https://docs.flutter.dev/packages-and-plugins', '__id': '3c7e21d187484bb883b93fb908829e66', '__job_id': 'job_3UuqZe0cSRanKTBVOe7WbgID2BWl'})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.chains import RetrievalQA
from langchain_google_vertexai import VertexAI


template = """You are an assistant for question-answering tasks.
Use the following pieces of retrieved context to answer the question.
If you don't know the answer, just say that you don't know.

Follow exactly those 4 steps:
1. Read the context below and aggregrate this data
Context : {context}
2. Answer the question using only this context, have detailed explanation
3. Show all the source URL for your answers
4. The answer should be in following format. Keep an eye on the changeline and don't truncate the link:

**Question**: {question}
\n**Answer**:
\n**Source**:
"""

prompt = ChatPromptTemplate.from_template(template)

llm = VertexAI(model_name="gemini-pro", temperature=0)

def generate_response(question):
    qa_chain = RetrievalQA.from_chain_type(
        llm,
        retriever=store.as_retriever(),
        chain_type_kwargs={"prompt": prompt}
    )
    result = qa_chain({"query": question})
    print(result["result"])

question = "How to remote debug Flutter app?"
generate_response(question)
# Out:
# **Question**: How to remote debug Flutter app?
#
# **Answer**: There are multiple ways to remote debug Flutter apps.
# 1. **Terminal**: Run 'flutter attach' or 'flutter attach -d deviceId' to attach from the terminal.
# 2. **VS Code**: Build the iOS version of the Flutter app in the Terminal.
#  - Run the 'flutter build ios --config-only --no-codesign --debug' command.
#  - Open the Flutter app directory in VS Code and select the device to debug.
#  - Click the debug icon to launch the app and wait for it to connect.
# 3. **Xcode**: Attach to the Flutter process in Xcode by going to 'Debug' > 'Attach to Process' > 'Runner'.
#  - Copy the Dart VM service URI from the Xcode debug area.
#  - In VS Code, open the command palette and type 'debug'.
#  - Click the 'Debug: Attach to Flutter on Device' command and paste the URI in the 'Paste an VM Service URI' box.
#
# **Source**:
# https://docs.flutter.dev/development/tools/debugging
